# %% [markdown]
# <a href="https://colab.research.google.com/github/grownsandip/ML_Algo/blob/main/kmeans_practise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **We are going to implement kmaeans  clustering algorithm on simple dataset**

# %%
import matplotlib.pyplot as plt
x=[4,5,10,4,3,11,16,27]
y=[21,19,24,17,16,25,24,27]
plt.scatter(x,y)
plt.show()

# %%
from sklearn.cluster import KMeans
data=list(zip(x,y))
inertias=[]
for i in range (1,9):
  kmeans=KMeans(n_clusters=i)
  kmeans.fit(data)
  inertias.append(kmeans.inertia_)
plt.plot(range(1,9),inertias,marker='o')
plt.title("Elbow method")
plt.xlabel("Number of clusters")
plt.ylabel("Inertia")
plt.show()

# %%
kmeans=KMeans(n_clusters=2)
kmeans.fit(data)
plt.scatter(x,y,c=kmeans.labels_)
plt.show()
